# %%
# Import required library
import turtle

# Creating the screen with name and size
screen = turtle.Screen()
screen.title("Bramkarz")
screen.setup(width=1000, height=600)

# Creating the left paddle
paddle1 = turtle.Turtle()
#Setting its speed as zero, it moves only when key is pressed
paddle1.speed(0)
#Setting shape, color, and size
paddle1.shape("square")
paddle1.color("blue")
paddle1.shapesize(stretch_wid=6, stretch_len=2)
paddle1.penup()
#The paddle is left-centered initially
paddle1.goto(400,0)


# Ball of circle shape
ball = turtle.Turtle()
#Setting the speed of ball to 0, it moves based on the dx and dy values
ball.speed(0)
#Setting shape, color, and size
ball.shape("circle")
ball.color("green")
ball.penup()
#Ball starts from the centre of the screen
ball.goto(-200, 0)
#Setting dx and dy that decide the speed of the ball
ball.dx = 2
ball.dy = 0

# Initializing the score of  players
player1 = 0


# Displaying the score
score = turtle.Turtle()
score.speed(0)
score.penup()
#Hiding the turtle to show text
score.hideturtle()
#Locating the scoreboard on top of the screen
score.goto(0, 260)
#Showing the score
score.write("Player: 0", align="center", font=("Courier", 20, "bold"))


# Function to move the left paddle up
def movePadRight():
    y = paddle1.ycor()  #Getting the current y-coordinated of the left paddle
    y += 15
    paddle1.sety(y)  #Updating the y-coordinated of the paddle


# Function to move the left paddle down
def movePadLeft():
    y = paddle1.ycor()  #Getting the current y-coordinated of the left paddle
    y += 15
    paddle1.sety(y)  #Updating the y-coordinated of the paddle

def moveBallUp():
    y = ball.ycor()  #Getting the current y-coordinated of the left paddle
    y -= 15
    ball.sety(y)  #Updating the y-coordinated of the paddle


def moveBallDown():
    y = ball.ycor()  #Getting the current y-coordinated of the left paddle
    y -= 15
    ball.sety(y)  #Updating the y-coordinated of the paddle




# Matching the Keyboard buttons to the above functions=
screen.listen()

screen.onkeypress(movePadRight, "Left")
screen.onkeypress(movePadLeft, "Right")
screen.onkeypress(moveBallDown, "Up")
screen.onkeypress(moveBallDown(), "Down")



#The main game
while True:
    #Updating the screen every time with the new changes
    screen.update()
    #Moving the ball by updating the coordinates
    ball.setx(ball.xcor()+ball.dx)
    ball.sety(ball.ycor()+ball.dy)
    # Checking if ball hits the top of the screen
    if ball.ycor() > 280:
        ball.sety(280)
        ball.dy *= -1 #Bouncing the ball
    # Checking if ball hits the bottom of the screen
    if ball.ycor() < -280:
        ball.sety(-280)
        ball.dy *= -1#Bouncing the ball
    #Checking if the ball hits the left or right walls, the player missed the hit
    if ball.xcor() > 500:
            player1 += 1 #Increasing the score of right player if left player missed
        #Starting ball again from center towards the opposite direction
            ball.goto(0, 0)

    #Updating score in the scoreboard
    score.clear()
    score.write("Player1 : {}".format(player1, player1), align="center", font=("Courier", 20, "bold"))

    #Checking if the right player hit the ball
    if (ball.xcor() > 360 and ball.xcor() < 370) and (paddle1.ycor() + 50 > ball.ycor() > paddle1.ycor() - 50):
        #Increasing score of right player and updating scoreboard
        ball.setx(0)
    #Increasing speed of the ball with the limit 7
    if(ball.dy>0 and ball.dy<7):#If dy is positive increasing dy
        ball.dy+=1
    elif(ball.dy<0 and ball.dy>-7):#else if dy is negative decreasing dy
        ball.dy-=1
    if(ball.dx>0 and ball.dx<7):#If dx is positive increasing dx
        ball.dx+=1
    elif(ball.dx<0 and ball.dx>-7): #else if dx is negative decreasing dx
        ball.dx-=1
        #Changing the direction of ball towards the left player
        ball.dx*=-1
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In [2], line 112
#     110 #Updating score in the scoreboard
#     111 score.clear()
# --> 112 score.write("Player1 : {}".format(player1, player1), align="center", font=("Courier", 20, "bold"))
#     114 #Checking if the right player hit the ball
#     115 if (ball.xcor() > 360 and ball.xcor() < 370) and (paddle1.ycor() + 50 > ball.ycor() > paddle1.ycor() - 50):
#     116     #Increasing score of right player and updating scoreboard
#
# File ~\AppData\Local\Programs\Python\Python38\lib\turtle.py:3432, in RawTurtle.write(self, arg, move, align, font)
#    3430     self.undobuffer.push(["seq"])
#    3431     self.undobuffer.cumulate = True
# -> 3432 end = self._write(str(arg), align.lower(), font)
#    3433 if move:
#    3434     x, y = self.pos()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\turtle.py:3403, in RawTurtle._write(self, txt, align, font)
#    3400 def _write(self, txt, align, font):
#    3401     """Performs the writing for write()
#    3402     """
# -> 3403     item, end = self.screen._write(self._position, txt, align, font,
#    3404                                                       self._pencolor)
#    3405     self.items.append(item)
#    3406     if self.undobuffer:
#
# File ~\AppData\Local\Programs\Python\Python38\lib\turtle.py:597, in TurtleScreenBase._write(self, pos, txt, align, font, pencolor)
#     595 y = y * self.yscale
#     596 anchor = {"left":"sw", "center":"s", "right":"se" }
# --> 597 item = self.cv.create_text(x-1, -y, text = txt, anchor = anchor[align],
#     598                                 fill = pencolor, font = font)
#     599 x0, y0, x1, y1 = self.cv.bbox(item)
#     600 self.cv.update()
#
# File <string>:1, in create_text(self, *args, **kw)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\tkinter\__init__.py:2810, in Canvas.create_text(self, *args, **kw)
#    2808 def create_text(self, *args, **kw):
#    2809     """Create text with coordinates x1,y1."""
# -> 2810     return self._create('text', args, kw)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\tkinter\__init__.py:2776, in Canvas._create(self, itemType, args, kw)
#    2774 else:
#    2775     cnf = {}
# -> 2776 return self.tk.getint(self.tk.call(
#    2777     self._w, 'create', itemType,
#    2778     *(args + self._options(cnf, kw))))
#
# TclError: invalid command name ".!canvas"
